# %%
# import numpy and pandas libraries for working with data
import numpy as np
import pandas as pd# Read in csv and store in a pandas dataframe
df = pd.read_csv('./data/linear-learner-MatchData.csv', sep=',' )

# %% [markdown]
# To verify that the csv was read correctly you can execute df.head() to get a list of the top 5 entries in your dataframe.

# %%
df.head(5)
# Out:
#    id  game_id    player_name  team  player_id   K  H   D  CP  UP  ...  G  B  \
# 0   1        1  Jack Riewoldt  RICH        577  12  6  18   5  14  ...  4  2
# 1   2        1     Alex Rance  RICH        576   9  6  15   8   5  ...  0  0
# 2   3        1    Corey Ellis  RICH        555   6  6  12   7   6  ...  0  0
# 3   4        1  Brandon Ellis  RICH        554  11  7  18   3  14  ...  0  1
# 4   5        1  Nick Vlastuin  RICH        584  10  2  12   3   7  ...  0  0
#
#    GA  G%  TG%   AF  CD_RP  T50   MG  SI
# 0   2  57   96  100   17.7    0  322  13
# 1   0   0  100   55   15.3    0  327   4
# 2   1   0   72   52   10.0    0  174   2
# 3   0   0   79   69    2.5    0  417   6
# 4   0   0   80   47    5.1    0  257   4
#
# [5 rows x 36 columns]

# %% [markdown]
# The csv has a lot of data that we don’t need right now, we should create a dataframe with only the information we care about. Let’s create a new pandas df with only the columns we require for the excercise.

# %%
# keep player name for readability and manual checking
data = df.loc[:, ['player_name', 'K', 'H', 'M', 'T', 'G', 'B', 'HO', 'FF', 'FA', 'AF']]# Remove player name as it is irrelevant for calcs
playerStats = data.loc[:, ['K', 'H','M','T','G','B','HO','FF','FA']]# confirm we got the data we wanted
data.head(10)
# Out:
#        player_name   K   H  M  T  G  B  HO  FF  FA   AF
# 0    Jack Riewoldt  12   6  7  1  4  2   0   1   0  100
# 1       Alex Rance   9   6  3  1  0  0   0   3   0   55
# 2      Corey Ellis   6   6  2  4  0  0   0   0   0   52
# 3    Brandon Ellis  11   7  3  3  0  1   0   0   0   69
# 4    Nick Vlastuin  10   2  3  3  0  0   0   1   3   47
# 5   Jacob Townsend   6   3  5  1  4  2   0   0   1   66
# 6     Jayden Short  12   4  2  1  0  1   0   0   1   52
# 7   Toby Nankervis   7   7  2  5  0  0  33   2   5   81
# 8  Kamdyn McIntosh  19   0  5  1  0  1   0   0   1   74
# 9    Dustin Martin  20  12  5  1  1  3   0   1   1  110

# %% [markdown]
# We now have an array of all the relevant player stats for every game of AFL in the 2018 season so far as well as the Fantasy Points that the player scored.
#
# Now AFL fantasy points are calculated by the following formula:
#
# Kick (3), Handball (2), Mark (3), Tackle (4), Goal (6), Behind (1), Hit Out (1), Free Kick For (1), Free Kick Against (-3)
#
# I’ve ordered these in the same order as our array so that we can create a weightings array in this order.

# %%
weightings = [3, 2, 3, 4, 6, 1, 1, 1, -3]

# %% [markdown]
# Before we run any ML algorithms we should verify that our data and weighting array are valid. Lets write a simple function to confirm this.
#
# This function will take an array of player stats and a vector of weights and multiply each stat by the relevant weight and sum them together to give us calculated Fantasy Points.

# %%
def calculate_fantasy_points(playerStats, Weightings):
    return np.dot(playerStats, np.transpose(weightings))

# %% [markdown]
# Now we can calculate fantasy points based on the weightings vector we have created and verify that they are indeed the correct weights.

# %%
# Calculate Fantasy Points
data['calculated'] = calculate_fantasy_points(playerStats, weightings)# Get the difference between actual points and predicted
data['diff'] = data['AF'] - calculate_fantasy_points(playerStats, weightings)# Take the sum of the difference over all data points and verify that is is zero
data['diff'].sum()
# Out:
# 0

# %% [markdown]
# At this stage we see that indeed, the weighting vector we created above is correct and does generate the Fantasy Points we would expect. The next step is to see if the SageMaker Linear Learner can find that weighting vector if it was unknown to us.

# %% [markdown]
# ##### Using SageMaker Linear Learner
# The first thing we need to do is to prepare the data in a format that SageMaker can use. The Linear Learner requires a numpy array of type float32.

# %%
# Kicks, handballs, goals etc
modelData = np.array(data.iloc[:, 1:10]).astype('float32')

# Actual Fantasy Points
target = np.array(data.iloc[:, 10]).astype('float32')

#Verify that the conversion worked
print(modelData[0])
# Out:
# [12.  6.  7.  1.  4.  2.  0.  1.  0.]

# %% [markdown]
# Next we need to import some librarys to communicate with the ML instances
# !!! Don't forget to change the bucket and prefix name as you like.!!!

# %%
import boto3
import sagemaker
import io
import os
import sagemaker.amazon.common as smac

# Create new sagemaker session
sess = sagemaker.Session()

# S3 bucket to export results to
bucket = "gcr-sm-workshop-henanwan"
prefix = "AFLFantasy/test"

# %%
# Use the IO buffer as dataset is small
buf = io.BytesIO()
smac.write_numpy_to_dense_tensor(buf, modelData, target)
buf.seek(0)

key = 'linearlearner'
boto3.resource('s3').Bucket(bucket).Object(os.path.join(prefix, 'train', key)).upload_fileobj(buf)

s3_train_data = 's3://{}/{}/train/{}'.format(bucket, prefix, key)
print('uploaded training data location: {}'.format(s3_train_data))

output_location = 's3://{}/{}/output'.format(bucket, prefix)
print('training artifacts will be uploaded to: {}'.format(output_location))
# Out:
# uploaded training data location: s3://gcr-sm-workshop-henanwan/AFLFantasy/test/train/linearlearner
# training artifacts will be uploaded to: s3://gcr-sm-workshop-henanwan/AFLFantasy/test/output

# %%
# Use all regions for ML model
containers = {'us-west-2': '174872318107.dkr.ecr.us-west-2.amazonaws.com/linear-learner:latest',
              'us-east-1': '382416733822.dkr.ecr.us-east-1.amazonaws.com/linear-learner:latest',
              'us-east-2': '404615174143.dkr.ecr.us-east-2.amazonaws.com/linear-learner:latest',
              'eu-west-1': '438346466558.dkr.ecr.eu-west-1.amazonaws.com/linear-learner:latest',
              'ap-northeast-1': '351501993468.dkr.ecr.ap-northeast-1.amazonaws.com/linear-learner:latest'}

# %% [markdown]
# Now that we’ve done some setup and configuration, we can look at running the model.

# %%
from sagemaker import get_execution_role
# role = get_execution_role()
role = 'arn:aws:iam::579019700964:role/service-role/AmazonSageMaker-ExecutionRole-20190429T111678'

linear = sagemaker.estimator.Estimator(containers[boto3.Session().region_name],
                                       role, 
                                       train_instance_count=1, 
                                       train_instance_type='ml.c4.xlarge',
                                       output_path=output_location,
                                       sagemaker_session=sess)

# %% [markdown]
# We need to set some model parameters for this model. Specifically we need to tell the linear learner that we have 9 parameters to fit, that we want a regression model, and most importantly we do not want to normalise the data.

# %%
linear.set_hyperparameters(feature_dim=9,
                           predictor_type='regressor',
                           normalize_data=False)

# %% [markdown]
# Now we are ready to deploy our model to an instance to run the linear learner and get results. To deploy this model we simply run the following codes.
# This will take a couple of minutes to provision and run and will let you know when it’s done.

# %%
linear.fit({'train': s3_train_data})
linear_predictor = linear.deploy(initial_instance_count=1,
                                 instance_type='ml.m4.xlarge')
# Out:
# 2019-09-03 05:52:10 Starting - Starting the training job...
# 2019-09-03 05:52:10 Starting - Launching requested ML instances...
# 2019-09-03 05:53:12 Starting - Preparing the instances for training......
# 2019-09-03 05:54:26 Downloading - Downloading input data...
# 2019-09-03 05:55:05 Training - Training image download completed. Training in progress.
# 2019-09-03 05:55:05 Uploading - Uploading generated training model
# 2019-09-03 05:55:05 Completed - Training job completed
#
# Docker entrypoint called with argument(s): train
# [09/03/2019 05:54:55 INFO 139895032825664] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'true', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [09/03/2019 05:54:55 INFO 139895032825664] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'normalize_data': u'False', u'feature_dim': u'9', u'predictor_type': u'regressor'}
# [09/03/2019 05:54:55 INFO 139895032825664] Final configuration: {u'loss_insensitivity': u'0.01', u'epochs': u'15', u'feature_dim': u'9', u'init_bias': u'0.0', u'lr_scheduler_factor': u'auto', u'num_calibration_samples': u'10000000', u'accuracy_top_k': u'3', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'num_point_for_scaler': u'10000', u'_log_level': u'info', u'quantile': u'0.5', u'bias_lr_mult': u'auto', u'lr_scheduler_step': u'auto', u'init_method': u'uniform', u'init_sigma': u'0.01', u'lr_scheduler_minimum_lr': u'auto', u'target_recall': u'0.8', u'num_models': u'auto', u'early_stopping_patience': u'3', u'momentum': u'auto', u'unbias_label': u'auto', u'wd': u'auto', u'optimizer': u'auto', u'_tuning_objective_metric': u'', u'early_stopping_tolerance': u'0.001', u'learning_rate': u'auto', u'_kvstore': u'auto', u'normalize_data': u'False', u'binary_classifier_model_selection_criteria': u'accuracy', u'use_lr_scheduler': u'true', u'target_precision': u'0.8', u'unbias_data': u'auto', u'init_scale': u'0.07', u'bias_wd_mult': u'auto', u'f_beta': u'1.0', u'mini_batch_size': u'1000', u'huber_delta': u'1.0', u'num_classes': u'1', u'predictor_type': u'regressor', u'beta_1': u'auto', u'loss': u'auto', u'beta_2': u'auto', u'_enable_profiler': u'false', u'normalize_label': u'auto', u'_num_gpus': u'auto', u'balance_multiclass_weights': u'false', u'positive_example_weight_mult': u'1.0', u'l1': u'auto', u'margin': u'1.0'}
# [09/03/2019 05:54:55 WARNING 139895032825664] Loggers have already been setup.
# Process 1 is a worker.
# [09/03/2019 05:54:55 INFO 139895032825664] Using default worker.
# [2019-09-03 05:54:55.928] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 15, "num_examples": 1, "num_bytes": 80000}
# [09/03/2019 05:54:55 INFO 139895032825664] Create Store: local
# [2019-09-03 05:54:55.955] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 26, "num_examples": 6, "num_bytes": 441760}
# [09/03/2019 05:54:55 INFO 139895032825664] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f3b88d6cfd0>
# [09/03/2019 05:54:55 INFO 139895032825664] Scaling model computed with parameters:
#  {'stdev_weight': None, 'stdev_label':
# [26.847862]
# <NDArray 1 @cpu(0)>, 'mean_label':
# [71.2738]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [9.7088 7.2886 4.1076 2.932  0.5448 0.4062 1.7472 0.952  0.9516]
# <NDArray 9 @cpu(0)>}
# [09/03/2019 05:54:55 INFO 139895032825664] nvidia-smi took: 0.0251479148865 secs to identify 0 gpus
# [09/03/2019 05:54:55 INFO 139895032825664] Number of GPUs being used: 0
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 6, "sum": 6.0, "min": 6}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 7, "sum": 7.0, "min": 7}, "Total Records Seen": {"count": 1, "max": 6522, "sum": 6522.0, "min": 6522}, "Max Records Seen Between Resets": {"count": 1, "max": 5522, "sum": 5522.0, "min": 5522}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1567490096.080234, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1567490096.080174}
#
# [2019-09-03 05:54:56.217] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 4, "duration": 137, "num_examples": 6, "num_bytes": 441760}
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.5333443603515625, "sum": 0.5333443603515625, "min": 0.5333443603515625}}, "EndTime": 1567490096.218092, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1567490096.218004}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.2408692626953124, "sum": 1.2408692626953124, "min": 1.2408692626953124}}, "EndTime": 1567490096.21818, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1567490096.218158}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.59006953125, "sum": 1.59006953125, "min": 1.59006953125}}, "EndTime": 1567490096.218248, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1567490096.218231}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1378980834960937, "sum": 1.1378980834960937, "min": 1.1378980834960937}}, "EndTime": 1567490096.218314, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1567490096.218295}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8529652099609375, "sum": 0.8529652099609375, "min": 0.8529652099609375}}, "EndTime": 1567490096.218379, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1567490096.218361}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8885929260253906, "sum": 0.8885929260253906, "min": 0.8885929260253906}}, "EndTime": 1567490096.218441, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1567490096.218422}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.1253681396484374, "sum": 1.1253681396484374, "min": 1.1253681396484374}}, "EndTime": 1567490096.2185, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1567490096.218484}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.88533525390625, "sum": 0.88533525390625, "min": 0.88533525390625}}, "EndTime": 1567490096.218562, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1567490096.218544}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8170893310546875, "sum": 0.8170893310546875, "min": 0.8170893310546875}}, "EndTime": 1567490096.218628, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1567490096.218611}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.17148173828125, "sum": 1.17148173828125, "min": 1.17148173828125}}, "EndTime": 1567490096.218691, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1567490096.218674}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9291603759765625, "sum": 0.9291603759765625, "min": 0.9291603759765625}}, "EndTime": 1567490096.218802, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1567490096.218781}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.7707186157226562, "sum": 0.7707186157226562, "min": 0.7707186157226562}}, "EndTime": 1567490096.218871, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1567490096.218853}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9499263793945313, "sum": 0.9499263793945313, "min": 0.9499263793945313}}, "EndTime": 1567490096.218931, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1567490096.218914}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8117160278320312, "sum": 0.8117160278320312, "min": 0.8117160278320312}}, "EndTime": 1567490096.218989, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1567490096.218973}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.9028078735351562, "sum": 0.9028078735351562, "min": 0.9028078735351562}}, "EndTime": 1567490096.219048, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1567490096.219031}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.721957275390625, "sum": 0.721957275390625, "min": 0.721957275390625}}, "EndTime": 1567490096.219115, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1567490096.219097}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8283419067382812, "sum": 0.8283419067382812, "min": 0.8283419067382812}}, "EndTime": 1567490096.219181, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1567490096.219163}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.8806903198242187, "sum": 0.8806903198242187, "min": 0.8806903198242187}}, "EndTime": 1567490096.21924, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1567490096.219224}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6733233642578125, "sum": 0.6733233642578125, "min": 0.6733233642578125}}, "EndTime": 1567490096.219299, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 0}, "StartTime": 1567490096.219283}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 1.
"Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1567490096.545289}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.10975818786621094, "sum": 0.10975818786621094, "min": 0.10975818786621094}}, "EndTime": 1567490096.545363, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1567490096.545347}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.07792543869018555, "sum": 0.07792543869018555, "min": 0.07792543869018555}}, "EndTime": 1567490096.545419, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1567490096.545402}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.17881414489746095, "sum": 0.17881414489746095, "min": 0.17881414489746095}}, "EndTime": 1567490096.545475, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1567490096.545459}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.1528278045654297, "sum": 0.1528278045654297, "min": 0.1528278045654297}}, "EndTime": 1567490096.545531, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1567490096.545515}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.1710339614868164, "sum": 0.1710339614868164, "min": 0.1710339614868164}}, "EndTime": 1567490096.545593, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 3}, "StartTime": 1567490096.545577}
#
# ...
#
# [09/03/2019 05:54:57 INFO 139895032825664] #quality_metric: host=algo-1, epoch=13, train mse_objective <loss>=0.00045767224431
# [09/03/2019 05:54:57 INFO 139895032825664] #early_stopping_criteria_metric: host=algo-1, epoch=13, criteria=mse_objective, value=0.00045767224431
# [09/03/2019 05:54:57 INFO 139895032825664] Epoch 13: Loss improved. Updating best model
# [09/03/2019 05:54:57 INFO 139895032825664] #progress_metric: host=algo-1, completed 93 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 6, "sum": 6.0, "min": 6}, "Number of Batches Since Last Reset": {"count": 1, "max": 6, "sum": 6.0, "min": 6}, "Number of Records Since Last Reset": {"count": 1, "max": 5522, "sum": 5522.0, "min": 5522}, "Total Batches Seen": {"count": 1, "max": 91, "sum": 91.0, "min": 91}, "Total Records Seen": {"count": 1, "max": 83830, "sum": 83830.0, "min": 83830}, "Max Records Seen Between Resets": {"count": 1, "max": 5522, "sum": 5522.0, "min": 5522}, "Reset Count": {"count": 1, "max": 16, "sum": 16.0, "min": 16}}, "EndTime": 1567490097.812813, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 13}, "StartTime": 1567490097.70978}
#
# [09/03/2019 05:54:57 INFO 139895032825664] #throughput_metric: host=algo-1, train throughput=53531.023353 records/second
# [2019-09-03 05:54:57.916] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 32, "duration": 103, "num_examples": 6, "num_bytes": 441760}
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.00022784952223300933, "sum": 0.00022784952223300933, "min": 0.00022784952223300933}}, "EndTime": 1567490097.916667, "Dimensions": {"model": 0, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1567490097.916586}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.0012471481561660766, "sum": 0.0012471481561660766, "min": 0.0012471481561660766}}, "EndTime": 1567490097.916764, "Dimensions": {"model": 1, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1567490097.916747}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.006767529392242432, "sum": 0.006767529392242432, "min": 0.006767529392242432}}, "EndTime": 1567490097.917003, "Dimensions": {"model": 2, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1567490097.916983}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.004082534694671631, "sum": 0.004082534694671631, "min": 0.004082534694671631}}, "EndTime": 1567490097.917055, "Dimensions": {"model": 3, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1567490097.917044}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.00031445731222629547, "sum": 0.00031445731222629547, "min": 0.00031445731222629547}}, "EndTime": 1567490097.917175, "Dimensions": {"model": 4, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1567490097.917159}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.0007193718433380127, "sum": 0.0007193718433380127, "min": 0.0007193718433380127}}, "EndTime": 1567490097.917386, "Dimensions": {"model": 5, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1567490097.917276}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.0007278264880180359, "sum": 0.0007278264880180359, "min": 0.0007278264880180359}}, "EndTime": 1567490097.917527, "Dimensions": {"model": 6, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1567490097.91751}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.001030169928073883, "sum": 0.001030169928073883, "min": 0.001030169928073883}}, "EndTime": 1567490097.917573, "Dimensions": {"model": 7, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1567490097.917562}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.0013826664805412293, "sum": 0.0013826664805412293, "min": 0.0013826664805412293}}, "EndTime": 1567490097.917688, "Dimensions": {"model": 8, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1567490097.917672}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.002827295827865601, "sum": 0.002827295827865601, "min": 0.002827295827865601}}, "EndTime": 1567490097.917859, "Dimensions": {"model": 9, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1567490097.917788}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.001013476848602295, "sum": 0.001013476848602295, "min": 0.001013476848602295}}, "EndTime": 1567490097.917915, "Dimensions": {"model": 10, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1567490097.917901}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.0009032658576965333, "sum": 0.0009032658576965333, "min": 0.0009032658576965333}}, "EndTime": 1567490097.918164, "Dimensions": {"model": 11, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1567490097.918142}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.00045592211484909057, "sum": 0.00045592211484909057, "min": 0.00045592211484909057}}, "EndTime": 1567490097.918311, "Dimensions": {"model": 12, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1567490097.918213}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.0013456337571144104, "sum": 0.0013456337571144104, "min": 0.0013456337571144104}}, "EndTime": 1567490097.918457, "Dimensions": {"model": 13, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1567490097.918436}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.0006759141027927398, "sum": 0.0006759141027927398, "min": 0.0006759141027927398}}, "EndTime": 1567490097.918603, "Dimensions": {"model": 14, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1567490097.918505}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.0006666003137826919, "sum": 0.0006666003137826919, "min": 0.0006666003137826919}}, "EndTime": 1567490097.918738, "Dimensions": {"model": 15, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1567490097.918716}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.02065714569091797, "sum": 0.02065714569091797, "min": 0.02065714569091797}}, "EndTime": 1567490097.918804, "Dimensions": {"model": 16, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1567490097.918786}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.021262831878662108, "sum": 0.021262831878662108, "min": 0.021262831878662108}}, "EndTime": 1567490097.919021, "Dimensions": {"model": 17, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1567490097.919}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.0195528621673584, "sum": 0.0195528621673584, "min": 0.0195528621673584}}, "EndTime": 1567490097.919086, "Dimensions": {"model": 18, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1567490097.919068}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.022956666946411134, "sum": 0.022956666946411134, "min": 0.022956666946411134}}, "EndTime": 1567490097.919307, "Dimensions": {"model": 19, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1567490097.919286}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.02091858329772949, "sum": 0.02091858329772949, "min": 0.02091858329772949}}, "EndTime": 1567490097.91937, "Dimensions": {"model": 20, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1567490097.919353}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.020141534805297852, "sum": 0.020141534805297852, "min": 0.020141534805297852}}, "EndTime": 1567490097.919585, "Dimensions": {"model": 21, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1567490097.919564}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.022037473678588868, "sum": 0.022037473678588868, "min": 0.022037473678588868}}, "EndTime": 1567490097.91965, "Dimensions": {"model": 22, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1567490097.919632}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.021665199661254884, "sum": 0.021665199661254884, "min": 0.021665199661254884}}, "EndTime": 1567490097.919866, "Dimensions": {"model": 23, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1567490097.919844}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.678207861328125, "sum": 0.678207861328125, "min": 0.678207861328125}}, "EndTime": 1567490097.919937, "Dimensions": {"model": 24, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1567490097.919915}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6801907958984375, "sum": 0.6801907958984375, "min": 0.6801907958984375}}, "EndTime": 1567490097.920146, "Dimensions": {"model": 25, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1567490097.920125}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6846434448242188, "sum": 0.6846434448242188, "min": 0.6846434448242188}}, "EndTime": 1567490097.920209, "Dimensions": {"model": 26, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1567490097.920192}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.673872900390625, "sum": 0.673872900390625, "min": 0.673872900390625}}, "EndTime": 1567490097.920427, "Dimensions": {"model": 27, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1567490097.920406}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6798309448242188, "sum": 0.6798309448242188, "min": 0.6798309448242188}}, "EndTime": 1567490097.920489, "Dimensions": {"model": 28, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1567490097.920473}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6876897094726563, "sum": 0.6876897094726563, "min": 0.6876897094726563}}, "EndTime": 1567490097.920723, "Dimensions": {"model": 29, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1567490097.920701}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6861941650390625, "sum": 0.6861941650390625, "min": 0.6861941650390625}}, "EndTime": 1567490097.920867, "Dimensions": {"model": 30, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1567490097.92077}
#
# #metrics {"Metrics": {"train_mse_objective": {"count": 1, "max": 0.6817244750976562, "sum": 0.6817244750976562, "min": 0.6817244750976562}}, "EndTime": 1567490097.921008, "Dimensions": {"model": 31, "Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1567490097.920988}
#
# [09/03/2019 05:54:57 INFO 139895032825664] #quality_metric: host=algo-1, epoch=14, train mse_objective <loss>=0.000227849522233
# [09/03/2019 05:54:57 INFO 139895032825664] #early_stopping_criteria_metric: host=algo-1, epoch=14, criteria=mse_objective, value=0.000227849522233
# [09/03/2019 05:54:57 INFO 139895032825664] Epoch 14: Loss improved. Updating best model
# [09/03/2019 05:54:57 INFO 139895032825664] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 6, "sum": 6.0, "min": 6}, "Number of Batches Since Last Reset": {"count": 1, "max": 6, "sum": 6.0, "min": 6}, "Number of Records Since Last Reset": {"count": 1, "max": 5522, "sum": 5522.0, "min": 5522}, "Total Batches Seen": {"count": 1, "max": 97, "sum": 97.0, "min": 97}, "Total Records Seen": {"count": 1, "max": 89352, "sum": 89352.0, "min": 89352}, "Max Records Seen Between Resets": {"count": 1, "max": 5522, "sum": 5522.0, "min": 5522}, "Reset Count": {"count": 1, "max": 17, "sum": 17.0, "min": 17}}, "EndTime": 1567490097.924292, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "Linear Learner", "epoch": 14}, "StartTime": 1567490097.813065}
#
# [09/03/2019 05:54:57 INFO 139895032825664] #throughput_metric: host=algo-1, train throughput=49565.0325883 records/second
# [09/03/2019 05:54:57 WARNING 139895032825664] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [09/03/2019 05:54:57 WARNING 139895032825664] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2019-09-03 05:54:57.930] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 34, "duration": 4, "num_examples": 1, "num_bytes": 80000}
# [2019-09-03 05:54:57.950] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 36, "duration": 16, "num_examples": 6, "num_bytes": 441760}
# [09/03/2019 05:54:57 INFO 139895032825664] #train_score (algo-1) : ('mse_objective', 0.133072713197724)
# [09/03/2019 05:54:57 INFO 139895032825664] #train_score (algo-1) : ('mse', 0.133072713197724)
# [09/03/2019 05:54:57 INFO 139895032825664] #train_score (algo-1) : ('absolute_loss', 0.28126888696545493)
# [09/03/2019 05:54:57 INFO 139895032825664] #quality_metric: host=algo-1, train mse_objective <loss>=0.133072713198
# [09/03/2019 05:54:57 INFO 139895032825664] #quality_metric: host=algo-1, train mse <loss>=0.133072713198
# [09/03/2019 05:54:57 INFO 139895032825664] #quality_metric: host=algo-1, train absolute_loss <loss>=0.281268886965
# [09/03/2019 05:54:57 INFO 139895032825664] Best model found for hyperparameters: {"lr_scheduler_step": 10, "wd": 0.0001, "optimizer": "adam", "lr_scheduler_factor": 0.99, "l1": 0.0, "learning_rate": 0.005, "lr_scheduler_minimum_lr": 1e-05}
# [09/03/2019 05:54:57 INFO 139895032825664] Saved checkpoint to "/tmp/tmp8Egdxf/mx-mod-0000.params"
# [09/03/2019 05:54:57 INFO 139895032825664] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 2125.549077987671, "sum": 2125.549077987671, "min": 2125.549077987671}, "finalize.time": {"count": 1, "max": 27.50110626220703, "sum": 27.50110626220703, "min": 27.50110626220703}, "initialize.time": {"count": 1, "max": 165.11821746826172, "sum": 165.11821746826172, "min": 165.11821746826172}, "check_early_stopping.time": {"count": 15, "max": 1.3058185577392578, "sum": 15.53201675415039, "min": 0.8420944213867188}, "setuptime": {"count": 1, "max": 24.415016174316406, "sum": 24.415016174316406, "min": 24.415016174316406}, "update.time": {"count": 15, "max": 146.18992805480957, "sum": 1837.571620941162, "min": 96.53186798095703}, "epochs": {"count": 1, "max": 15, "sum": 15.0, "min": 15}}, "EndTime": 1567490097.961717, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "Linear Learner"}, "StartTime": 1567490095.912056}
# Billable seconds: 40
# -------------------------------------------------------------------------------------------!

# %% [markdown]
# ##### Accessing the results
# Once the model has been trained, we can send new data to the model and obtain predictions. In this case we are just going to send it the training data back and see how close it got to finding the correct weights.

# %%
# Set up
from sagemaker.predictor import csv_serializer, json_deserializer

linear_predictor.content_type = 'text/csv'
linear_predictor.serializer = csv_serializer
linear_predictor.deserializer = json_deserializer

# %% [markdown]
# Pass all the data to the predictor and get all the results back

# %%
predictions = []
for array in modelData:
    result = linear_predictor.predict(array)
    predictions += [r['score'] for r in result['predictions']]

# %%
predictions = np.array(predictions)
# Push into our pandas dataframe
data['Predicted'] = predictions.astype(int)
data.head(5)
# Out:
#      player_name   K  H  M  T  G  B  HO  FF  FA   AF  calculated  diff  \
# 0  Jack Riewoldt  12  6  7  1  4  2   0   1   0  100         100     0
# 1     Alex Rance   9  6  3  1  0  0   0   3   0   55          55     0
# 2    Corey Ellis   6  6  2  4  0  0   0   0   0   52          52     0
# 3  Brandon Ellis  11  7  3  3  0  1   0   0   0   69          69     0
# 4  Nick Vlastuin  10  2  3  3  0  0   0   1   3   47          47     0
#
#    Predicted
# 0         99
# 1         54
# 2         52
# 3         68
# 4         46

# %%
# envaluation
y_predicted = data['Predicted']
y = data['calculated']

# %%
def evaluationModel(y,y_pre):
    accuracy_cnt = 0
    for i,j in zip(y,y_pre):
        if abs(i-j) <= 1:
            accuracy_cnt += 1
    accuracy_rate = float(accuracy_cnt) / len(y_predicted)
    print ('test samples：{0}'.format(len(y_predicted)))
    print ('accurate samples：{0}'.format(accuracy_cnt))
    print ('accuracy rate：{0:.3f}'.format((accuracy_rate)))

# %%
evaluationModel(y,y_predicted)
# Out:
# test samples：5522
# accurate samples：5486
# accuracy rate：0.993

# %% [markdown]
# The results were very close.
# And Sagemaker make it possible to deliver the ease of setting up the model, and just a little domain knowledge required to run this simple regression.

# %% [markdown]
# ##### (Optional) Delete the Endpoint
#
# If you're ready to be done with this notebook, please run the delete_endpoint line in the cell below. This will remove the hosted endpoint you created and avoid any charges from a stray instance being left on.

# %%
sagemaker.Session().delete_endpoint(linear_predictor.endpoint)
